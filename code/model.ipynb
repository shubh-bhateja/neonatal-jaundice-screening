# %%
import os
import cv2
import numpy as np

image_folder = "/Users/shubhbhateja/College/minor_project/images"

images = []
image_ids = []

for file in sorted(os.listdir(image_folder)):
    path = os.path.join(image_folder, file)
    img = cv2.imread(path)
    if img is None:
        continue
    
    img = cv2.resize(img, (512,512), interpolation=cv2.INTER_AREA)
    images.append(img)
    image_ids.append(file)

images = np.array(images)

print("Images Shape:", images.shape)
# Out:
# Images Shape: (2235, 512, 512, 3)

# %%
import pandas as pd

clinical_df = pd.read_csv("/Users/shubhbhateja/College/minor_project/NeoJaundice/chd_jaundice_published_2.csv")
print(clinical_df.head())
# Out:
#    patient_id   image_idx gender  gestational_age  age(day)  weight  \
# 0           3  0003-1.jpg      F               40       5.2    3280
# 1           3  0003-2.jpg      F               40       5.2    3280
# 2           3  0003-3.jpg      F               40       5.2    3280
# 3          35  0035-1.jpg      M               39       8.7    3760
# 4          35  0035-2.jpg      M               39       8.7    3760
#
#    blood(mg/dL)  Treatment
# 0           3.9          0
# 1           3.9          0
# 2           3.9          0
# 3          12.2          0
# 4          12.2          0

# %%
import matplotlib.pyplot as plt
plt.figure(figsize=(15,4))

plt.subplot(1,3,1)
plt.hist(clinical_df["weight"], bins=30)
plt.title("Weight Distribution")
plt.subplot(1,3,2)
plt.hist(clinical_df["gestational_age"], bins=30)
plt.title("Weight Distribution")

plt.subplot(1,3,3)
plt.hist(clinical_df["blood(mg/dL)"], bins=30)
plt.title("Weight Distribution")
plt.tight_layout()

plt.show()

# %%
plt.figure(figsize=(15,4))
plt.subplot(1,3,1)
plt.hist(clinical_df["weight"], bins=30)
plt.title("Weight Distribution")
plt.xlabel("Weight (kg)")
plt.ylabel("Frequency")
# Out:
# Text(0, 0.5, 'Frequency')
